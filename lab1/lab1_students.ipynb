# %%
import pandas as pd
df = pd.read_csv('StudentsPerformance.csv')

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %% [markdown]
# Wyświetlanie częśćiowe ( 5- 5 wierszy )

# %%
df.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
for element in df['lunch']:
    print(element)
# Out:
# standard
# standard
# standard
# free/reduced
# standard
# standard
# standard
# free/reduced
# free/reduced
# free/reduced
# standard
# standard
# standard
# standard
# standard
# standard
# standard
# free/reduced
# free/reduced
# free/reduced
# standard
# free/reduced
# standard
# standard
# free/reduced
# free/reduced
# standard
# standard
# standard
# standard
# standard
# standard
# free/reduced
# standard
# standard
# standard
# standard
# free/reduced
# free/reduced
# free/reduced
# free/reduced
# standard
# standard
# free/reduced
# free/reduced
# standard
# standard
# standard
# free/reduced
# standard
# standard
# free/reduced
# standard
# standard
# free/reduced
# free/reduced
# standard
# standard
# standard
# free/reduced
# free/reduced
# free/reduced
# free/reduced
# standard
# standard
# standard
# free/reduced
# standard
# free/reduced
# standard
# free/reduced
# standard
# free/reduced
# free/reduced
# standard
# free/reduced
# standard
# standard
# standard
# ...

# %% [markdown]
# ekstrakcja nazw kolumn

# %%
columns = df.columns
columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %% [markdown]
# sortowanie

# %%
df.sort_values(['math score'])
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 59   female        group C            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 787  female        group B                some college      standard
# 145  female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 625    male        group D                some college      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# 962  female        group E          associate's degree      standard
# 149    male        group E          associate's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# sortowanie po dwóch kolumnach (sortuje po pierwszy ame jeśli jest egzekwo to dodatkowo sortuje po drugim)

# %%
new_df = df.sort_values(['math score', 'writing score'])
#jeśli nie przypiszę do zmiennej to mogę to wyświetlić ale nie mogę potem z tego korzystać

# %%
new_df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 59   female        group C            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 787  female        group B                some college      standard
# 145  female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 451  female        group E                some college      standard
# 625    male        group D                some college      standard
# 458  female        group E           bachelor's degree      standard
# 916    male        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [raw]
# Tworzenie nowej kolumny
# Piszę z dużej litery żeby rozróżnić które ja stworzyłam.

# %%
df['Total score'] = 0

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# Sumowanie elementów
# !Zawsze najpierw wiersze - potem kolumny

# %%
df['Total score'] = df.iloc[:,5:8].sum(axis=1)
#sumowanie dla kolumn od 5 do 8, czyli 6,7,8

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# Ususwanie kolumn (i wierszy)

# %%
df = df.drop(['Total score'], axis = 1)

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...
